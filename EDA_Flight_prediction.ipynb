# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# display all the columns of the dataframe
pd.pandas.set_option('display.max_columns', None)

# %%
dataset = pd.read_excel('/Users/anilreddykunta/Desktop/Anil/PYTHON/Untitled Folder/5-Days-Live-EDA-and-Feature-Engineering-main/Flight Prediction/Data_Train.xlsx')

# %%
dataset.head()
# Out:
#        Airline Date_of_Journey    Source Destination                  Route  \
# 0       IndiGo      24/03/2019  Banglore   New Delhi              BLR → DEL
# 1    Air India       1/05/2019   Kolkata    Banglore  CCU → IXR → BBI → BLR
# 2  Jet Airways       9/06/2019     Delhi      Cochin  DEL → LKO → BOM → COK
# 3       IndiGo      12/05/2019   Kolkata    Banglore        CCU → NAG → BLR
# 4       IndiGo      01/03/2019  Banglore   New Delhi        BLR → NAG → DEL
#
#   Dep_Time  Arrival_Time Duration Total_Stops Additional_Info  Price
# 0    22:20  01:10 22 Mar   2h 50m    non-stop         No info   3897
# 1    05:50         13:15   7h 25m     2 stops         No info   7662
# 2    09:25  04:25 10 Jun      19h     2 stops         No info  13882
# 3    18:05         23:30   5h 25m      1 stop         No info   6218
# 4    16:50         21:35   4h 45m      1 stop         No info  13302

# %%
dataset['Destination'].unique()
# Out:
# array(['New Delhi', 'Banglore', 'Cochin', 'Kolkata', 'Delhi', 'Hyderabad'],
#       dtype=object)

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10683 entries, 0 to 10682
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Airline          10683 non-null  object
#  1   Date_of_Journey  10683 non-null  object
#  2   Source           10683 non-null  object
#  3   Destination      10683 non-null  object
#  4   Route            10682 non-null  object
#  5   Dep_Time         10683 non-null  object
#  6   Arrival_Time     10683 non-null  object
#  7   Duration         10683 non-null  object
#  8   Total_Stops      10682 non-null  object
#  9   Additional_Info  10683 non-null  object
#  10  Price            10683 non-null  int64
# dtypes: int64(1), object(10)
# memory usage: 918.2+ KB

# %%
dataset['Date'] = dataset['Date_of_Journey'].str.split('/').str[0]
dataset['Month'] = dataset['Date_of_Journey'].str.split('/').str[1]
dataset['year'] = dataset['Date_of_Journey'].str.split('/').str[2]

# %%
dataset['Date']
# Out:
# 0        24
# 1         1
# 2         9
# 3        12
# 4        01
#          ..
# 10678     9
# 10679    27
# 10680    27
# 10681    01
# 10682     9
# Name: Date, Length: 10683, dtype: object

# %%
dataset.head()
# Out:
#        Airline Date_of_Journey    Source Destination                  Route  \
# 0       IndiGo      24/03/2019  Banglore   New Delhi              BLR → DEL
# 1    Air India       1/05/2019   Kolkata    Banglore  CCU → IXR → BBI → BLR
# 2  Jet Airways       9/06/2019     Delhi      Cochin  DEL → LKO → BOM → COK
# 3       IndiGo      12/05/2019   Kolkata    Banglore        CCU → NAG → BLR
# 4       IndiGo      01/03/2019  Banglore   New Delhi        BLR → NAG → DEL
#
#   Dep_Time  Arrival_Time Duration Total_Stops Additional_Info  Price Date  \
# 0    22:20  01:10 22 Mar   2h 50m    non-stop         No info   3897   24
# 1    05:50         13:15   7h 25m     2 stops         No info   7662    1
# 2    09:25  04:25 10 Jun      19h     2 stops         No info  13882    9
# 3    18:05         23:30   5h 25m      1 stop         No info   6218   12
# 4    16:50         21:35   4h 45m      1 stop         No info  13302   01
#
#   Month  year
# 0    03  2019
# 1    05  2019
# 2    06  2019
# ...

# %%
dataset['Date'] =  dataset['Date_of_Journey'].apply(lambda x:x.split('/')[0])  
dataset['Month'] = dataset['Date_of_Journey'].apply(lambda x:x.split('/')[1])  
dataset['year'] = dataset['Date_of_Journey'].apply(lambda x:x.split('/')[2])

# %%
dataset
# Out:
#            Airline Date_of_Journey    Source Destination  \
# 0           IndiGo      24/03/2019  Banglore   New Delhi
# 1        Air India       1/05/2019   Kolkata    Banglore
# 2      Jet Airways       9/06/2019     Delhi      Cochin
# 3           IndiGo      12/05/2019   Kolkata    Banglore
# 4           IndiGo      01/03/2019  Banglore   New Delhi
# ...            ...             ...       ...         ...
# 10678     Air Asia       9/04/2019   Kolkata    Banglore
# 10679    Air India      27/04/2019   Kolkata    Banglore
# 10680  Jet Airways      27/04/2019  Banglore       Delhi
# 10681      Vistara      01/03/2019  Banglore   New Delhi
# 10682    Air India       9/05/2019     Delhi      Cochin
#
#                        Route Dep_Time  Arrival_Time Duration Total_Stops  \
# 0                  BLR → DEL    22:20  01:10 22 Mar   2h 50m    non-stop
# 1      CCU → IXR → BBI → BLR    05:50         13:15   7h 25m     2 stops
# ...

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10683 entries, 0 to 10682
# Data columns (total 14 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Airline          10683 non-null  object
#  1   Date_of_Journey  10683 non-null  object
#  2   Source           10683 non-null  object
#  3   Destination      10683 non-null  object
#  4   Route            10682 non-null  object
#  5   Dep_Time         10683 non-null  object
#  6   Arrival_Time     10683 non-null  object
#  7   Duration         10683 non-null  object
#  8   Total_Stops      10682 non-null  object
#  9   Additional_Info  10683 non-null  object
#  10  Price            10683 non-null  int64
#  11  Date             10683 non-null  object
#  12  Month            10683 non-null  object
#  13  year             10683 non-null  object
# dtypes: int64(1), object(13)
# memory usage: 1.1+ MB

# %%
dataset['Date'] = dataset['Date'].astype(int)
dataset['Month'] = dataset['Month'].astype(int)
dataset['year'] = dataset['year'].astype(int)

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10683 entries, 0 to 10682
# Data columns (total 14 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Airline          10683 non-null  object
#  1   Date_of_Journey  10683 non-null  object
#  2   Source           10683 non-null  object
#  3   Destination      10683 non-null  object
#  4   Route            10682 non-null  object
#  5   Dep_Time         10683 non-null  object
#  6   Arrival_Time     10683 non-null  object
#  7   Duration         10683 non-null  object
#  8   Total_Stops      10682 non-null  object
#  9   Additional_Info  10683 non-null  object
#  10  Price            10683 non-null  int64
#  11  Date             10683 non-null  int64
#  12  Month            10683 non-null  int64
#  13  year             10683 non-null  int64
# dtypes: int64(4), object(10)
# memory usage: 1.1+ MB

# %%
dataset.drop('Date_of_Journey', axis=1, inplace=True) # axis = 1 columns

# %%
dataset.head()
# Out:
#        Airline    Source Destination                  Route Dep_Time  \
# 0       IndiGo  Banglore   New Delhi              BLR → DEL    22:20
# 1    Air India   Kolkata    Banglore  CCU → IXR → BBI → BLR    05:50
# 2  Jet Airways     Delhi      Cochin  DEL → LKO → BOM → COK    09:25
# 3       IndiGo   Kolkata    Banglore        CCU → NAG → BLR    18:05
# 4       IndiGo  Banglore   New Delhi        BLR → NAG → DEL    16:50
#
#    Arrival_Time Duration Total_Stops Additional_Info  Price  Date  Month  year
# 0  01:10 22 Mar   2h 50m    non-stop         No info   3897    24      3  2019
# 1         13:15   7h 25m     2 stops         No info   7662     1      5  2019
# 2  04:25 10 Jun      19h     2 stops         No info  13882     9      6  2019
# 3         23:30   5h 25m      1 stop         No info   6218    12      5  2019
# 4         21:35   4h 45m      1 stop         No info  13302     1      3  2019

# %%
dataset['Arrival_Time'] = dataset['Arrival_Time'].str.split(" ").str[0]

# %%
dataset['Arrival_Time']
# Out:
# 0        01:10
# 1        13:15
# 2        04:25
# 3        23:30
# 4        21:35
#          ...
# 10678    22:25
# 10679    23:20
# 10680    11:20
# 10681    14:10
# 10682    19:15
# Name: Arrival_Time, Length: 10683, dtype: object

# %%
dataset['Arrival_Time_hour'] = dataset['Arrival_Time'].str.split(':').str[0]

# %%
dataset['Arrival_Time_min'] = dataset['Arrival_Time'].str.split(':').str[1]

# %%
dataset['Arrival_Time_hour']
# Out:
# 0        01
# 1        13
# 2        04
# 3        23
# 4        21
#          ..
# 10678    22
# 10679    23
# 10680    11
# 10681    14
# 10682    19
# Name: Arrival_Time_hour, Length: 10683, dtype: object

# %%
dataset['Arrival_Time'] =  dataset['Arrival_Time'].apply(lambda x:x.split('/')[0])
dataset['Arrival_Time']
# Out:
# 0        01:10
# 1        13:15
# 2        04:25
# 3        23:30
# 4        21:35
#          ...
# 10678    22:25
# 10679    23:20
# 10680    11:20
# 10681    14:10
# 10682    19:15
# Name: Arrival_Time, Length: 10683, dtype: object

# %%
dataset.head()
# Out:
#        Airline    Source Destination                  Route Dep_Time  \
# 0       IndiGo  Banglore   New Delhi              BLR → DEL    22:20
# 1    Air India   Kolkata    Banglore  CCU → IXR → BBI → BLR    05:50
# 2  Jet Airways     Delhi      Cochin  DEL → LKO → BOM → COK    09:25
# 3       IndiGo   Kolkata    Banglore        CCU → NAG → BLR    18:05
# 4       IndiGo  Banglore   New Delhi        BLR → NAG → DEL    16:50
#
#   Arrival_Time Duration Total_Stops Additional_Info  Price  Date  Month  year  \
# 0        01:10   2h 50m    non-stop         No info   3897    24      3  2019
# 1        13:15   7h 25m     2 stops         No info   7662     1      5  2019
# 2        04:25      19h     2 stops         No info  13882     9      6  2019
# 3        23:30   5h 25m      1 stop         No info   6218    12      5  2019
# 4        21:35   4h 45m      1 stop         No info  13302     1      3  2019
#
#   Arrival_Time_hour Arrival_Time_min
# 0                01               10
# ...

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10683 entries, 0 to 10682
# Data columns (total 15 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Airline            10683 non-null  object
#  1   Source             10683 non-null  object
#  2   Destination        10683 non-null  object
#  3   Route              10682 non-null  object
#  4   Dep_Time           10683 non-null  object
#  5   Arrival_Time       10683 non-null  object
#  6   Duration           10683 non-null  object
#  7   Total_Stops        10682 non-null  object
#  8   Additional_Info    10683 non-null  object
#  9   Price              10683 non-null  int64
#  10  Date               10683 non-null  int64
#  11  Month              10683 non-null  int64
#  12  year               10683 non-null  int64
#  13  Arrival_Time_hour  10683 non-null  object
#  14  Arrival_Time_min   10683 non-null  object
# dtypes: int64(4), object(11)
# memory usage: 1.2+ MB

# %%
dataset['Arrival_Time_hour'] = dataset['Arrival_Time_hour'].astype(int)
dataset['Arrival_Time_min'] = dataset['Arrival_Time_min'].astype(int)

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10683 entries, 0 to 10682
# Data columns (total 15 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Airline            10683 non-null  object
#  1   Source             10683 non-null  object
#  2   Destination        10683 non-null  object
#  3   Route              10682 non-null  object
#  4   Dep_Time           10683 non-null  object
#  5   Arrival_Time       10683 non-null  object
#  6   Duration           10683 non-null  object
#  7   Total_Stops        10682 non-null  object
#  8   Additional_Info    10683 non-null  object
#  9   Price              10683 non-null  int64
#  10  Date               10683 non-null  int64
#  11  Month              10683 non-null  int64
#  12  year               10683 non-null  int64
#  13  Arrival_Time_hour  10683 non-null  int64
#  14  Arrival_Time_min   10683 non-null  int64
# dtypes: int64(6), object(9)
# memory usage: 1.2+ MB

# %%
dataset.head()
# Out:
#        Airline    Source Destination                  Route Dep_Time  \
# 0       IndiGo  Banglore   New Delhi              BLR → DEL    22:20
# 1    Air India   Kolkata    Banglore  CCU → IXR → BBI → BLR    05:50
# 2  Jet Airways     Delhi      Cochin  DEL → LKO → BOM → COK    09:25
# 3       IndiGo   Kolkata    Banglore        CCU → NAG → BLR    18:05
# 4       IndiGo  Banglore   New Delhi        BLR → NAG → DEL    16:50
#
#   Arrival_Time Duration Total_Stops Additional_Info  Price  Date  Month  year  \
# 0        01:10   2h 50m    non-stop         No info   3897    24      3  2019
# 1        13:15   7h 25m     2 stops         No info   7662     1      5  2019
# 2        04:25      19h     2 stops         No info  13882     9      6  2019
# 3        23:30   5h 25m      1 stop         No info   6218    12      5  2019
# 4        21:35   4h 45m      1 stop         No info  13302     1      3  2019
#
#    Arrival_Time_hour  Arrival_Time_min
# 0                  1                10
# ...

# %%
dataset.drop('Arrival_Time', axis=1,inplace= True)

# %%
dataset.head()
# Out:
#        Airline    Source Destination                  Route Dep_Time Duration  \
# 0       IndiGo  Banglore   New Delhi              BLR → DEL    22:20   2h 50m
# 1    Air India   Kolkata    Banglore  CCU → IXR → BBI → BLR    05:50   7h 25m
# 2  Jet Airways     Delhi      Cochin  DEL → LKO → BOM → COK    09:25      19h
# 3       IndiGo   Kolkata    Banglore        CCU → NAG → BLR    18:05   5h 25m
# 4       IndiGo  Banglore   New Delhi        BLR → NAG → DEL    16:50   4h 45m
#
#   Total_Stops Additional_Info  Price  Date  Month  year  Arrival_Time_hour  \
# 0    non-stop         No info   3897    24      3  2019                  1
# 1     2 stops         No info   7662     1      5  2019                 13
# 2     2 stops         No info  13882     9      6  2019                  4
# 3      1 stop         No info   6218    12      5  2019                 23
# 4      1 stop         No info  13302     1      3  2019                 21
#
#    Arrival_Time_min
# 0                10
# ...

# %%
dataset['Dep_Time'] = dataset['Dep_Time'].str.split(" ").str[0]

# %%
dataset["Dep_Time"]
# Out:
# 0        22:20
# 1        05:50
# 2        09:25
# 3        18:05
# 4        16:50
#          ...
# 10678    19:55
# 10679    20:45
# 10680    08:20
# 10681    11:30
# 10682    10:55
# Name: Dep_Time, Length: 10683, dtype: object

# %%
dataset['Dep_Time_hour'] = dataset['Dep_Time'].str.split(':').str[0]
dataset['Dep_Time_min'] = dataset['Dep_Time'].str.split(':').str[1]

# %%
dataset['Dep_Time_hour']
# Out:
# 0        22
# 1        05
# 2        09
# 3        18
# 4        16
#          ..
# 10678    19
# 10679    20
# 10680    08
# 10681    11
# 10682    10
# Name: Dep_Time_hour, Length: 10683, dtype: object

# %%
dataset['Dep_Time_min']
# Out:
# 0        20
# 1        50
# 2        25
# 3        05
# 4        50
#          ..
# 10678    55
# 10679    45
# 10680    20
# 10681    30
# 10682    55
# Name: Dep_Time_min, Length: 10683, dtype: object

# %%
dataset.head()
# Out:
#        Airline    Source Destination                  Route Dep_Time Duration  \
# 0       IndiGo  Banglore   New Delhi              BLR → DEL    22:20   2h 50m
# 1    Air India   Kolkata    Banglore  CCU → IXR → BBI → BLR    05:50   7h 25m
# 2  Jet Airways     Delhi      Cochin  DEL → LKO → BOM → COK    09:25      19h
# 3       IndiGo   Kolkata    Banglore        CCU → NAG → BLR    18:05   5h 25m
# 4       IndiGo  Banglore   New Delhi        BLR → NAG → DEL    16:50   4h 45m
#
#   Total_Stops Additional_Info  Price  Date  Month  year  Arrival_Time_hour  \
# 0    non-stop         No info   3897    24      3  2019                  1
# 1     2 stops         No info   7662     1      5  2019                 13
# 2     2 stops         No info  13882     9      6  2019                  4
# 3      1 stop         No info   6218    12      5  2019                 23
# 4      1 stop         No info  13302     1      3  2019                 21
#
# ...

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10683 entries, 0 to 10682
# Data columns (total 16 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Airline            10683 non-null  object
#  1   Source             10683 non-null  object
#  2   Destination        10683 non-null  object
#  3   Route              10682 non-null  object
#  4   Dep_Time           10683 non-null  object
#  5   Duration           10683 non-null  object
#  6   Total_Stops        10682 non-null  object
#  7   Additional_Info    10683 non-null  object
#  8   Price              10683 non-null  int64
#  9   Date               10683 non-null  int64
#  10  Month              10683 non-null  int64
#  11  year               10683 non-null  int64
#  12  Arrival_Time_hour  10683 non-null  int64
#  13  Arrival_Time_min   10683 non-null  int64
#  14  Dep_Time_hour      10683 non-null  object
#  15  Dep_Time_min       10683 non-null  object
# ...

# %%
dataset['Dep_Time_hour'] = dataset['Dep_Time_hour'].astype(int)
dataset['Dep_Time_min'] = dataset['Dep_Time_min'].astype(int)

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10683 entries, 0 to 10682
# Data columns (total 16 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Airline            10683 non-null  object
#  1   Source             10683 non-null  object
#  2   Destination        10683 non-null  object
#  3   Route              10682 non-null  object
#  4   Dep_Time           10683 non-null  object
#  5   Duration           10683 non-null  object
#  6   Total_Stops        10682 non-null  object
#  7   Additional_Info    10683 non-null  object
#  8   Price              10683 non-null  int64
#  9   Date               10683 non-null  int64
#  10  Month              10683 non-null  int64
#  11  year               10683 non-null  int64
#  12  Arrival_Time_hour  10683 non-null  int64
#  13  Arrival_Time_min   10683 non-null  int64
#  14  Dep_Time_hour      10683 non-null  int64
#  15  Dep_Time_min       10683 non-null  int64
# ...

# %%
dataset.drop('Dep_Time', axis=1,inplace= True)

# %%
dataset.head()
# Out:
#        Airline    Source Destination                  Route Duration  \
# 0       IndiGo  Banglore   New Delhi              BLR → DEL   2h 50m
# 1    Air India   Kolkata    Banglore  CCU → IXR → BBI → BLR   7h 25m
# 2  Jet Airways     Delhi      Cochin  DEL → LKO → BOM → COK      19h
# 3       IndiGo   Kolkata    Banglore        CCU → NAG → BLR   5h 25m
# 4       IndiGo  Banglore   New Delhi        BLR → NAG → DEL   4h 45m
#
#   Total_Stops Additional_Info  Price  Date  Month  year  Arrival_Time_hour  \
# 0    non-stop         No info   3897    24      3  2019                  1
# 1     2 stops         No info   7662     1      5  2019                 13
# 2     2 stops         No info  13882     9      6  2019                  4
# 3      1 stop         No info   6218    12      5  2019                 23
# 4      1 stop         No info  13302     1      3  2019                 21
#
#    Arrival_Time_min  Dep_Time_hour  Dep_Time_min
# 0                10             22            20
# ...

# %%
dataset['Total_Stops'].unique()
# Out:
# array(['non-stop', '2 stops', '1 stop', '3 stops', nan, '4 stops'],
#       dtype=object)

# %%
dataset['Total_Stops'].mode()
# Out:
# 0    1 stop
# Name: Total_Stops, dtype: object

# %%
dataset['Total_Stops'].str.split(' ').str[0]
# Out:
# 0        non-stop
# 1               2
# 2               2
# 3               1
# 4               1
#            ...
# 10678    non-stop
# 10679    non-stop
# 10680    non-stop
# 10681    non-stop
# 10682           2
# Name: Total_Stops, Length: 10683, dtype: object

# %%
dataset['Total_Stops']=dataset['Total_Stops'].map({'non-stop':0,'1 stop':1,'2 stops':2, '3 stops':3, '4 stops':4, 'nan':1})

# %%
dataset.head(25)
# Out:
#               Airline    Source Destination                  Route Duration  \
# 0              IndiGo  Banglore   New Delhi              BLR → DEL   2h 50m
# 1           Air India   Kolkata    Banglore  CCU → IXR → BBI → BLR   7h 25m
# 2         Jet Airways     Delhi      Cochin  DEL → LKO → BOM → COK      19h
# 3              IndiGo   Kolkata    Banglore        CCU → NAG → BLR   5h 25m
# 4              IndiGo  Banglore   New Delhi        BLR → NAG → DEL   4h 45m
# 5            SpiceJet   Kolkata    Banglore              CCU → BLR   2h 25m
# 6         Jet Airways  Banglore   New Delhi        BLR → BOM → DEL  15h 30m
# 7         Jet Airways  Banglore   New Delhi        BLR → BOM → DEL   21h 5m
# 8         Jet Airways  Banglore   New Delhi        BLR → BOM → DEL  25h 30m
# 9   Multiple carriers     Delhi      Cochin        DEL → BOM → COK   7h 50m
# 10          Air India     Delhi      Cochin        DEL → BLR → COK  13h 15m
# ...

# %%
dataset['Total_Stops'].dtypes
# Out:
# dtype('float64')

# %%
dataset.drop('Route', axis=1, inplace= True)

# %%
dataset.head()
# Out:
#        Airline    Source Destination Duration  Total_Stops Additional_Info  \
# 0       IndiGo  Banglore   New Delhi   2h 50m          0.0         No info
# 1    Air India   Kolkata    Banglore   7h 25m          2.0         No info
# 2  Jet Airways     Delhi      Cochin      19h          2.0         No info
# 3       IndiGo   Kolkata    Banglore   5h 25m          1.0         No info
# 4       IndiGo  Banglore   New Delhi   4h 45m          1.0         No info
#
#    Price  Date  Month  year  Arrival_Time_hour  Arrival_Time_min  \
# 0   3897    24      3  2019                  1                10
# 1   7662     1      5  2019                 13                15
# 2  13882     9      6  2019                  4                25
# 3   6218    12      5  2019                 23                30
# 4  13302     1      3  2019                 21                35
#
#    Dep_Time_hour  Dep_Time_min
# 0             22            20
# 1              5            50
# ...

# %%
dataset['Additional_Info'].unique()
# Out:
# array(['No info', 'In-flight meal not included',
#        'No check-in baggage included', '1 Short layover', 'No Info',
#        '1 Long layover', 'Change airports', 'Business class',
#        'Red-eye flight', '2 Long layover'], dtype=object)

# %%
dataset['Airline'].unique()
# Out:
# array(['IndiGo', 'Air India', 'Jet Airways', 'SpiceJet',
#        'Multiple carriers', 'GoAir', 'Vistara', 'Air Asia',
#        'Vistara Premium economy', 'Jet Airways Business',
#        'Multiple carriers Premium economy', 'Trujet'], dtype=object)

# %%
dataset['Destination'].unique()
# Out:
# array(['New Delhi', 'Banglore', 'Cochin', 'Kolkata', 'Delhi', 'Hyderabad'],
#       dtype=object)

# %%
dataset['Source'].unique()
# Out:
# array(['Banglore', 'Kolkata', 'Delhi', 'Chennai', 'Mumbai'], dtype=object)

# %% [markdown]
# # one-hot encoding

# %%
pd.get_dummies(dataset,columns=['Airline','Destination','Source','Additional_Info'],drop_first=True)
# Out:
#       Duration  Total_Stops  Price  Date  Month  year  Arrival_Time_hour  \
# 0       2h 50m          0.0   3897    24      3  2019                  1
# 1       7h 25m          2.0   7662     1      5  2019                 13
# 2          19h          2.0  13882     9      6  2019                  4
# 3       5h 25m          1.0   6218    12      5  2019                 23
# 4       4h 45m          1.0  13302     1      3  2019                 21
# ...        ...          ...    ...   ...    ...   ...                ...
# 10678   2h 30m          0.0   4107     9      4  2019                 22
# 10679   2h 35m          0.0   4145    27      4  2019                 23
# 10680       3h          0.0   7229    27      4  2019                 11
# 10681   2h 40m          0.0  12648     1      3  2019                 14
# 10682   8h 20m          2.0  11753     9      5  2019                 19
#
#        Arrival_Time_min  Dep_Time_hour  Dep_Time_min  Airline_Air India  \
# ...

# %%
dataset.head(2)
# Out:
#      Airline    Source Destination Duration  Total_Stops Additional_Info  \
# 0     IndiGo  Banglore   New Delhi   2h 50m          0.0         No info
# 1  Air India   Kolkata    Banglore   7h 25m          2.0         No info
#
#    Price  Date  Month  year  Arrival_Time_hour  Arrival_Time_min  \
# 0   3897    24      3  2019                  1                10
# 1   7662     1      5  2019                 13                15
#
#    Dep_Time_hour  Dep_Time_min
# 0             22            20
# 1              5            50

# %% [raw]
# # label encoding
#
# qualification
#
# ph - 5
# masters - 4
# BE - 3
# 12 - 2
# 10 - 1

# %%
pd.get_dummies(dataset,columns=['Additional_Info'],drop_first=True)
# Out:
#            Airline    Source Destination Duration  Total_Stops  Price  Date  \
# 0           IndiGo  Banglore   New Delhi   2h 50m          0.0   3897    24
# 1        Air India   Kolkata    Banglore   7h 25m          2.0   7662     1
# 2      Jet Airways     Delhi      Cochin      19h          2.0  13882     9
# 3           IndiGo   Kolkata    Banglore   5h 25m          1.0   6218    12
# 4           IndiGo  Banglore   New Delhi   4h 45m          1.0  13302     1
# ...            ...       ...         ...      ...          ...    ...   ...
# 10678     Air Asia   Kolkata    Banglore   2h 30m          0.0   4107     9
# 10679    Air India   Kolkata    Banglore   2h 35m          0.0   4145    27
# 10680  Jet Airways  Banglore       Delhi       3h          0.0   7229    27
# 10681      Vistara  Banglore   New Delhi   2h 40m          0.0  12648     1
# 10682    Air India     Delhi      Cochin   8h 20m          2.0  11753     9
#
# ...

# %%
dataset = pd.get_dummies(dataset,columns=['Airline','Destination','Source','Additional_Info'],drop_first=True)

# %%
dataset.head()
# Out:
#   Duration  Total_Stops  Price  Date  Month  year  Arrival_Time_hour  \
# 0   2h 50m          0.0   3897    24      3  2019                  1
# 1   7h 25m          2.0   7662     1      5  2019                 13
# 2      19h          2.0  13882     9      6  2019                  4
# 3   5h 25m          1.0   6218    12      5  2019                 23
# 4   4h 45m          1.0  13302     1      3  2019                 21
#
#    Arrival_Time_min  Dep_Time_hour  Dep_Time_min  Airline_Air India  \
# 0                10             22            20                  0
# 1                15              5            50                  1
# 2                25              9            25                  0
# 3                30             18             5                  0
# 4                35             16            50                  0
#
#    Airline_GoAir  Airline_IndiGo  Airline_Jet Airways  \
# 0              0               1                    0
# ...

# %%
dataset.shape
# Out:
# (10683, 39)
