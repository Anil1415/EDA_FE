# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# display all columns of the dataframe

pd.pandas.set_option('display.max_columns', None)

# %%
df_original = pd.read_csv('adult.csv')

# %%
df_original.head()
# Out:
#    39          State-gov   77516   Bachelors   13        Never-married  \
# 0  50   Self-emp-not-inc   83311   Bachelors   13   Married-civ-spouse
# 1  38            Private  215646     HS-grad    9             Divorced
# 2  53            Private  234721        11th    7   Married-civ-spouse
# 3  28            Private  338409   Bachelors   13   Married-civ-spouse
# 4  37            Private  284582     Masters   14   Married-civ-spouse
#
#          Adm-clerical   Not-in-family   White     Male   2174   0   40  \
# 0     Exec-managerial         Husband   White     Male      0   0   13
# 1   Handlers-cleaners   Not-in-family   White     Male      0   0   40
# 2   Handlers-cleaners         Husband   Black     Male      0   0   40
# 3      Prof-specialty            Wife   Black   Female      0   0   40
# 4     Exec-managerial            Wife   White   Female      0   0   40
#
#     United-States   <=50K
# 0   United-States   <=50K
# 1   United-States   <=50K
# 2   United-States   <=50K
# ...

# %%
columns = ['Age', 'Work Class', 'Final Weight', 'Education', 'Education Number', 'Marital Status', 'Occupation', 'Relationship', 'Race', 'Sex', 'Capital Gain', 'Capital Loss', 'Hours-per-week', 'Native Country', 'Class']

# %%
df = pd.read_csv('adult.csv',  names= columns)

# %%
df.head()
# Out:
#    Age         Work Class  Final Weight   Education  Education Number  \
# 0   39          State-gov         77516   Bachelors                13
# 1   50   Self-emp-not-inc         83311   Bachelors                13
# 2   38            Private        215646     HS-grad                 9
# 3   53            Private        234721        11th                 7
# 4   28            Private        338409   Bachelors                13
#
#         Marital Status          Occupation    Relationship    Race      Sex  \
# 0        Never-married        Adm-clerical   Not-in-family   White     Male
# 1   Married-civ-spouse     Exec-managerial         Husband   White     Male
# 2             Divorced   Handlers-cleaners   Not-in-family   White     Male
# 3   Married-civ-spouse   Handlers-cleaners         Husband   Black     Male
# 4   Married-civ-spouse      Prof-specialty            Wife   Black   Female
#
#    Capital Gain  Capital Loss  Hours-per-week  Native Country   Class
# ...

# %%
df.tail()
# Out:
#        Age     Work Class  Final Weight    Education  Education Number  \
# 32556   27        Private        257302   Assoc-acdm                12
# 32557   40        Private        154374      HS-grad                 9
# 32558   58        Private        151910      HS-grad                 9
# 32559   22        Private        201490      HS-grad                 9
# 32560   52   Self-emp-inc        287927      HS-grad                 9
#
#             Marital Status          Occupation Relationship    Race      Sex  \
# 32556   Married-civ-spouse        Tech-support         Wife   White   Female
# 32557   Married-civ-spouse   Machine-op-inspct      Husband   White     Male
# 32558              Widowed        Adm-clerical    Unmarried   White   Female
# 32559        Never-married        Adm-clerical    Own-child   White     Male
# 32560   Married-civ-spouse     Exec-managerial         Wife   White   Female
#
#        Capital Gain  Capital Loss  Hours-per-week  Native Country   Class
# ...

# %%
df.shape
# Out:
# (32561, 15)

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# # Data types

# %%
df.dtypes
# Out:
# Age                  int64
# Work Class          object
# Final Weight         int64
# Education           object
# Education Number     int64
# Marital Status      object
# Occupation          object
# Relationship        object
# Race                object
# Sex                 object
# Capital Gain         int64
# Capital Loss         int64
# Hours-per-week       int64
# Native Country      object
# Class               object
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32561 entries, 0 to 32560
# Data columns (total 15 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Age               32561 non-null  int64
#  1   Work Class        32561 non-null  object
#  2   Final Weight      32561 non-null  int64
#  3   Education         32561 non-null  object
#  4   Education Number  32561 non-null  int64
#  5   Marital Status    32561 non-null  object
#  6   Occupation        32561 non-null  object
#  7   Relationship      32561 non-null  object
#  8   Race              32561 non-null  object
#  9   Sex               32561 non-null  object
#  10  Capital Gain      32561 non-null  int64
#  11  Capital Loss      32561 non-null  int64
#  12  Hours-per-week    32561 non-null  int64
#  13  Native Country    32561 non-null  object
#  14  Class             32561 non-null  object
# dtypes: int64(6), object(9)
# memory usage: 3.7+ MB

# %%
df.columns
# df.keys()
# Out:
# Index(['Age', 'Work Class', 'Final Weight', 'Education', 'Education Number',
#        'Marital Status', 'Occupation', 'Relationship', 'Race', 'Sex',
#        'Capital Gain', 'Capital Loss', 'Hours-per-week', 'Native Country',
#        'Class'],
#       dtype='object')

# %% [markdown]
# ## In data analysis, analyze to find the below stuff
#
# 1. Missing values
# 2. All the numerical variables
# 3. Distribution of the numerical variables
# 4. Categorical variables
# 5. outliers
# 6. Relationship b/w independent and dependent features
# 7. Correlations (Feature selection)

# %%
# missing values

# %%
# No null values, Need to look for any special characters
df.isnull().sum()
# Out:
# Age                 0
# Work Class          0
# Final Weight        0
# Education           0
# Education Number    0
# Marital Status      0
# Occupation          0
# Relationship        0
# Race                0
# Sex                 0
# Capital Gain        0
# Capital Loss        0
# Hours-per-week      0
# Native Country      0
# Class               0
# dtype: int64

# %%
df.sample(50) # found some special character = ' ?'
# Out:
#        Age         Work Class  Final Weight      Education  Education Number  \
# 24207   39            Private        278557      Assoc-voc                11
# 3656    43            Private        245842        HS-grad                 9
# 6797    49            Private        235683   Some-college                10
# 16068   28            Private        149769        HS-grad                 9
# 18706   73   Self-emp-not-inc        336007        HS-grad                 9
# 29147   50            Private         94081        HS-grad                 9
# 8446    78                  ?         27979        HS-grad                 9
# 9145    44          Local-gov        177240    Prof-school                15
# 9519    31            Private        454508           11th                 7
# 8605    21            Private        285457   Some-college                10
# 11675   36       Self-emp-inc         27408      Assoc-voc                11
# ...

# %%
df[df == ' ?']  =np.nan

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32561 entries, 0 to 32560
# Data columns (total 15 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Age               32561 non-null  int64
#  1   Work Class        32561 non-null  object
#  2   Final Weight      32561 non-null  int64
#  3   Education         32561 non-null  object
#  4   Education Number  32561 non-null  int64
#  5   Marital Status    32561 non-null  object
#  6   Occupation        32561 non-null  object
#  7   Relationship      32561 non-null  object
#  8   Race              32561 non-null  object
#  9   Sex               32561 non-null  object
#  10  Capital Gain      32561 non-null  int64
#  11  Capital Loss      32561 non-null  int64
#  12  Hours-per-week    32561 non-null  int64
#  13  Native Country    32561 non-null  object
#  14  Class             32561 non-null  object
# dtypes: int64(6), object(9)
# memory usage: 3.7+ MB

# %%
df.isnull().sum()
# Out:
# Age                    0
# Work Class          1836
# Final Weight           0
# Education              0
# Education Number       0
# Marital Status         0
# Occupation          1843
# Relationship           0
# Race                   0
# Sex                    0
# Capital Gain           0
# Capital Loss           0
# Hours-per-week         0
# Native Country       583
# Class                  0
# dtype: int64

# %%
# since they are categorical features, replace with mode

# %%
df['Native Country'].unique()
# Out:
# array([' United-States', ' Cuba', ' Jamaica', ' India', nan, ' Mexico',
#        ' South', ' Puerto-Rico', ' Honduras', ' England', ' Canada',
#        ' Germany', ' Iran', ' Philippines', ' Italy', ' Poland',
#        ' Columbia', ' Cambodia', ' Thailand', ' Ecuador', ' Laos',
#        ' Taiwan', ' Haiti', ' Portugal', ' Dominican-Republic',
#        ' El-Salvador', ' France', ' Guatemala', ' China', ' Japan',
#        ' Yugoslavia', ' Peru', ' Outlying-US(Guam-USVI-etc)', ' Scotland',
#        ' Trinadad&Tobago', ' Greece', ' Nicaragua', ' Vietnam', ' Hong',
#        ' Ireland', ' Hungary', ' Holand-Netherlands'], dtype=object)

# %%
df.count()
# Out:
# Age                 32561
# Work Class          30725
# Final Weight        32561
# Education           32561
# Education Number    32561
# Marital Status      32561
# Occupation          30718
# Relationship        32561
# Race                32561
# Sex                 32561
# Capital Gain        32561
# Capital Loss        32561
# Hours-per-week      32561
# Native Country      31978
# Class               32561
# dtype: int64

# %%
# columns with missing values (NAN values)
features_with_na  = [features for features in df.columns if df[features].isnull().sum()>1]

# %%
features_with_na
# Out:
# ['Work Class', 'Occupation', 'Native Country']

# %%
for feature in features_with_na:
    print(feature, np.round(df[feature].isnull().mean()*100,4),'%       missing values')
# Out:
# Work Class 5.6386 %       missing values
# Occupation 5.6601 %       missing values
# Native Country 1.7905 %       missing values

# %%
df['Native Country'] = df['Native Country'].replace(' ?', np.nan)

# %%
for feature in features_with_na:# .fillna(df['Work Class'].mode()[0])
    df[feature] = df[feature].fillna(df[feature].mode()[0])

# %%
df['Native Country'].isnull().sum()
# Out:
# 0

# %%
df.isnull().sum()
# Out:
# Age                 0
# Work Class          0
# Final Weight        0
# Education           0
# Education Number    0
# Marital Status      0
# Occupation          0
# Relationship        0
# Race                0
# Sex                 0
# Capital Gain        0
# Capital Loss        0
# Hours-per-week      0
# Native Country      0
# Class               0
# dtype: int64

# %%
data =df.copy()


for feature in features_with_na:
    # make a variable that indicate 1 if observation was missing
    data[feature] = np.where(data[feature].isnull(),1,0)
    
    # lets calculate the mean sales price where information is missing or present
    
    data.groupby(feature)['Class'].mode().plot.bar()
    
    plt.title(feature)
    plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Input In [136], in <cell line: 4>()
#       6 data[feature] = np.where(data[feature].isnull(),1,0)
#       8 # lets calculate the mean sales price where information is missing or present
# ---> 10 data.groupby(feature)['Class'].mode().plot.bar()
#      12 plt.title(feature)
#      13 plt.show()
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/groupby/generic.py:1338, in DataFrameGroupBy.__getitem__(self, key)
#    1329 if isinstance(key, tuple) and len(key) > 1:
#    1330     # if len == 1, then it becomes a SeriesGroupBy and this is actually
#    1331     # valid syntax, so don't raise warning
#    1332     warnings.warn(
#    1333         "Indexing with multiple keys (implicitly converted to a tuple "
#    1334         "of keys) will be deprecated, use a list instead.",
#    1335         FutureWarning,
# ...

# %%
df.duplicated().sum()
# Out:
# 24

# %%
df[df.duplicated()]
# Out:
#        Age         Work Class  Final Weight      Education  Education Number  \
# 4881    25            Private        308144      Bachelors                13
# 5104    90            Private         52386   Some-college                10
# 9171    21            Private        250051   Some-college                10
# 11631   20            Private        107658   Some-college                10
# 13084   25            Private        195994        1st-4th                 2
# 15059   21            Private        243368      Preschool                 1
# 17040   46            Private        173243        HS-grad                 9
# 18555   30            Private        144593        HS-grad                 9
# 18698   19            Private         97261        HS-grad                 9
# 21318   19            Private        138153   Some-college                10
# 21490   19            Private        146679   Some-college                10
# ...

# %%
df.describe().T
# Out:
#                     count           mean            std      min       25%  \
# Age               32561.0      38.581647      13.640433     17.0      28.0
# Final Weight      32561.0  189778.366512  105549.977697  12285.0  117827.0
# Education Number  32561.0      10.080679       2.572720      1.0       9.0
# Capital Gain      32561.0    1077.648844    7385.292085      0.0       0.0
# Capital Loss      32561.0      87.303830     402.960219      0.0       0.0
# Hours-per-week    32561.0      40.437456      12.347429      1.0      40.0
#
#                        50%       75%        max
# Age                   37.0      48.0       90.0
# Final Weight      178356.0  237051.0  1484705.0
# Education Number      10.0      12.0       16.0
# Capital Gain           0.0       0.0    99999.0
# Capital Loss           0.0       0.0     4356.0
# Hours-per-week        40.0      45.0       99.0

# %%
df.isnull().sum()
# Out:
# Age                 0
# Work Class          0
# Final Weight        0
# Education           0
# Education Number    0
# Marital Status      0
# Occupation          0
# Relationship        0
# Race                0
# Sex                 0
# Capital Gain        0
# Capital Loss        0
# Hours-per-week      0
# Native Country      0
# Class               0
# dtype: int64

# %%
df.groupby('Sex').describe().T
# Out:
# Sex                           Female          Male
# Age              count  1.077100e+04  2.179000e+04
#                  mean   3.685823e+01  3.943355e+01
#                  std    1.401370e+01  1.337063e+01
#                  min    1.700000e+01  1.700000e+01
#                  25%    2.500000e+01  2.900000e+01
#                  50%    3.500000e+01  3.800000e+01
#                  75%    4.600000e+01  4.800000e+01
#                  max    9.000000e+01  9.000000e+01
# Final Weight     count  1.077100e+04  2.179000e+04
#                  mean   1.857463e+05  1.917714e+05
#                  std    1.029861e+05  1.067407e+05
#                  min    1.228500e+04  1.376900e+04
#                  25%    1.173630e+05  1.182008e+05
#                  50%    1.760770e+05  1.801400e+05
#                  75%    2.283315e+05  2.411462e+05
#                  max    1.484705e+06  1.455435e+06
# Education Number count  1.077100e+04  2.179000e+04
# ...

# %%
df.groupby('Sex').describe()['Hours-per-week']
# Out:
#            count       mean        std  min   25%   50%   75%   max
# Sex
#  Female  10771.0  36.410361  11.811300  1.0  30.0  40.0  40.0  99.0
#  Male    21790.0  42.428086  12.119755  1.0  40.0  40.0  49.0  99.0

# %%
df.groupby('Sex').describe()['Hours-per-week'].T
# Out:
# Sex          Female          Male
# count  10771.000000  21790.000000
# mean      36.410361     42.428086
# std       11.811300     12.119755
# min        1.000000      1.000000
# 25%       30.000000     40.000000
# 50%       40.000000     40.000000
# 75%       40.000000     49.000000
# max       99.000000     99.000000

# %%
ab_90 = df[df['Age']>=90]

# %%
ab_90.shape
# Out:
# (43, 15)

# %%
max(df['Hours-per-week'])
# Out:
# 99

# %%
# 85 members worked 99 a Week
df[df['Hours-per-week'] == max(df['Hours-per-week'])] #['Sex']
# Out:
#        Age         Work Class  Final Weight      Education  Education Number  \
# 935     37            Private        176900        HS-grad                 9
# 1172    25            Private        404616        Masters                14
# 1887    55   Self-emp-not-inc        184425   Some-college                10
# 3578    37       Self-emp-inc        382802      Doctorate                16
# 4086    50            Private        174964           10th                 6
# ...    ...                ...           ...            ...               ...
# 30992   40       Self-emp-inc        104235        Masters                14
# 31681   43            Private        266324        HS-grad                 9
# 31699   43   Self-emp-not-inc        163108   Some-college                10
# 32469   58       Self-emp-inc        181974      Doctorate                16
# 32531   30            Private         33811      Bachelors                13
#
# ...

# %%
# 85 members worked 99 a Week
ind=df[df['Hours-per-week'] == max(df['Hours-per-week'])]['Sex'].index

# %%
df.iloc[ind]
# Out:
#        Age         Work Class  Final Weight      Education  Education Number  \
# 935     37            Private        176900        HS-grad                 9
# 1172    25            Private        404616        Masters                14
# 1887    55   Self-emp-not-inc        184425   Some-college                10
# 3578    37       Self-emp-inc        382802      Doctorate                16
# 4086    50            Private        174964           10th                 6
# ...    ...                ...           ...            ...               ...
# 30992   40       Self-emp-inc        104235        Masters                14
# 31681   43            Private        266324        HS-grad                 9
# 31699   43   Self-emp-not-inc        163108   Some-college                10
# 32469   58       Self-emp-inc        181974      Doctorate                16
# 32531   30            Private         33811      Bachelors                13
#
# ...

# %%
df.sample(5)
# Out:
#        Age         Work Class  Final Weight     Education  Education Number  \
# 30281   31            Private        183000   Prof-school                15
# 6249    24            Private        325596     Bachelors                13
# 12737   50            Private        196975       HS-grad                 9
# 31953   37            Private        103121     Bachelors                13
# 31799   52   Self-emp-not-inc         42984   Prof-school                15
#
#             Marital Status        Occupation    Relationship    Race      Sex  \
# 30281        Never-married      Tech-support   Not-in-family   White     Male
# 6249         Never-married      Adm-clerical       Own-child   White     Male
# 12737   Married-civ-spouse      Craft-repair         Husband   White     Male
# 31953   Married-civ-spouse   Exec-managerial            Wife   White   Female
# 31799   Married-civ-spouse    Prof-specialty         Husband   White     Male
#
# ...

# %%
df[df.duplicated()]
# Out:
#        Age         Work Class  Final Weight      Education  Education Number  \
# 4881    25            Private        308144      Bachelors                13
# 5104    90            Private         52386   Some-college                10
# 9171    21            Private        250051   Some-college                10
# 11631   20            Private        107658   Some-college                10
# 13084   25            Private        195994        1st-4th                 2
# 15059   21            Private        243368      Preschool                 1
# 17040   46            Private        173243        HS-grad                 9
# 18555   30            Private        144593        HS-grad                 9
# 18698   19            Private         97261        HS-grad                 9
# 21318   19            Private        138153   Some-college                10
# 21490   19            Private        146679   Some-college                10
# ...

# %%
df[df.duplicated()].shape
# Out:
# (24, 15)

# %%
df.dtypes[df.dtypes == 'O']
# Out:
# Work Class        object
# Education         object
# Marital Status    object
# Occupation        object
# Relationship      object
# Race              object
# Sex               object
# Native Country    object
# Class             object
# dtype: object

# %%
 df.dtypes[df.dtypes == 'O'].index
# Out:
# Index(['Work Class', 'Education', 'Marital Status', 'Occupation',
#        'Relationship', 'Race', 'Sex', 'Native Country', 'Class'],
#       dtype='object')

# %%
cat_df = df.dtypes[df.dtypes == 'O'].index

# %%
df[cat_df].describe().T
# Out:
#                 count unique                  top   freq
# Work Class      32561      8              Private  24532
# Education       32561     16              HS-grad  10501
# Marital Status  32561      7   Married-civ-spouse  14976
# Occupation      32561     14       Prof-specialty   5983
# Relationship    32561      6              Husband  13193
# Race            32561      5                White  27816
# Sex             32561      2                 Male  21790
# Native Country  32561     41        United-States  29753
# Class           32561      2                <=50K  24720

# %%
df['Relationship'].value_counts()
# Out:
#  Husband           13193
#  Not-in-family      8305
#  Own-child          5068
#  Unmarried          3446
#  Wife               1568
#  Other-relative      981
# Name: Relationship, dtype: int64

# %%
df['Relationship'].count # husband count? Visualisation
# Out:
# <bound method Series.count of 0         Not-in-family
# 1               Husband
# 2         Not-in-family
# 3               Husband
# 4                  Wife
#               ...
# 32556              Wife
# 32557           Husband
# 32558         Unmarried
# 32559         Own-child
# 32560              Wife
# Name: Relationship, Length: 32561, dtype: object>

# %%
df[df['Relationship'] == ' Husband']
# Out:
#        Age         Work Class  Final Weight      Education  Education Number  \
# 1       50   Self-emp-not-inc         83311      Bachelors                13
# 3       53            Private        234721           11th                 7
# 7       52   Self-emp-not-inc        209642        HS-grad                 9
# 9       42            Private        159449      Bachelors                13
# 10      37            Private        280464   Some-college                10
# ...    ...                ...           ...            ...               ...
# 32550   43   Self-emp-not-inc         27242   Some-college                10
# 32551   32            Private         34066           10th                 6
# 32552   43            Private         84661      Assoc-voc                11
# 32554   53            Private        321865        Masters                14
# 32557   40            Private        154374        HS-grad                 9
#
# ...

# %%
df.loc[ind]
# Out:
#        Age         Work Class  Final Weight      Education  Education Number  \
# 935     37            Private        176900        HS-grad                 9
# 1172    25            Private        404616        Masters                14
# 1887    55   Self-emp-not-inc        184425   Some-college                10
# 3578    37       Self-emp-inc        382802      Doctorate                16
# 4086    50            Private        174964           10th                 6
# ...    ...                ...           ...            ...               ...
# 30992   40       Self-emp-inc        104235        Masters                14
# 31681   43            Private        266324        HS-grad                 9
# 31699   43   Self-emp-not-inc        163108   Some-college                10
# 32469   58       Self-emp-inc        181974      Doctorate                16
# 32531   30            Private         33811      Bachelors                13
#
# ...

# %%
df['Education'][0:20]
# Out:
# 0         Bachelors
# 1         Bachelors
# 2           HS-grad
# 3              11th
# 4         Bachelors
# 5           Masters
# 6               9th
# 7           HS-grad
# 8           Masters
# 9         Bachelors
# 10     Some-college
# 11        Bachelors
# 12        Bachelors
# 13       Assoc-acdm
# 14        Assoc-voc
# 15          7th-8th
# 16          HS-grad
# 17          HS-grad
# 18             11th
# 19          Masters
# Name: Education, dtype: object

# %%
df['Education'][0:20:2]
# Out:
# 0         Bachelors
# 2           HS-grad
# 4         Bachelors
# 6               9th
# 8           Masters
# 10     Some-college
# 12        Bachelors
# 14        Assoc-voc
# 16          HS-grad
# 18             11th
# Name: Education, dtype: object

# %%
df.head()
# Out:
#    Age         Work Class  Final Weight   Education  Education Number  \
# 0   39          State-gov         77516   Bachelors                13
# 1   50   Self-emp-not-inc         83311   Bachelors                13
# 2   38            Private        215646     HS-grad                 9
# 3   53            Private        234721        11th                 7
# 4   28            Private        338409   Bachelors                13
#
#         Marital Status          Occupation    Relationship    Race      Sex  \
# 0        Never-married        Adm-clerical   Not-in-family   White     Male
# 1   Married-civ-spouse     Exec-managerial         Husband   White     Male
# 2             Divorced   Handlers-cleaners   Not-in-family   White     Male
# 3   Married-civ-spouse   Handlers-cleaners         Husband   Black     Male
# 4   Married-civ-spouse      Prof-specialty            Wife   Black   Female
#
#    Capital Gain  Capital Loss  Hours-per-week  Native Country   Class
# ...

# %%
# No missing values in 'Capital Loss' and 'Capital Gain', 'Age'
df[df['Capital Loss'].isnull()==True]
# Out:
# Empty DataFrame
# Columns: [Age, Work Class, Final Weight, Education, Education Number, Marital Status, Occupation, Relationship, Race, Sex, Capital Gain, Capital Loss, Hours-per-week, Native Country, Class]
# Index: []

# %%
df.shape
# Out:
# (32561, 15)

# %%
df[df['Age'].isnull()==True]
# Out:
# Empty DataFrame
# Columns: [Age, Work Class, Final Weight, Education, Education Number, Marital Status, Occupation, Relationship, Race, Sex, Capital Gain, Capital Loss, Hours-per-week, Native Country, Class]
# Index: []

# %%
df.iloc[0:5,:5]
# Out:
#    Age         Work Class  Final Weight   Education  Education Number
# 0   39          State-gov         77516   Bachelors                13
# 1   50   Self-emp-not-inc         83311   Bachelors                13
# 2   38            Private        215646     HS-grad                 9
# 3   53            Private        234721        11th                 7
# 4   28            Private        338409   Bachelors                13

# %%
df['Occupation'].unique()
# Out:
# array([' Adm-clerical', ' Exec-managerial', ' Handlers-cleaners',
#        ' Prof-specialty', ' Other-service', ' Sales', ' Craft-repair',
#        ' Transport-moving', ' Farming-fishing', ' Machine-op-inspct',
#        ' Tech-support', ' Protective-serv', ' Armed-Forces',
#        ' Priv-house-serv'], dtype=object)

# %%
df['Work Class'].unique()
# Out:
# array([' State-gov', ' Self-emp-not-inc', ' Private', ' Federal-gov',
#        ' Local-gov', ' Self-emp-inc', ' Without-pay', ' Never-worked'],
#       dtype=object)

# %%
df[df['Work Class'] == ' ?']
# Out:
# Empty DataFrame
# Columns: [Age, Work Class, Final Weight, Education, Education Number, Marital Status, Occupation, Relationship, Race, Sex, Capital Gain, Capital Loss, Hours-per-week, Native Country, Class]
# Index: []

# %%
df[df['Native Country'] == ' ?'] # space before ?
# Out:
# Empty DataFrame
# Columns: [Age, Work Class, Final Weight, Education, Education Number, Marital Status, Occupation, Relationship, Race, Sex, Capital Gain, Capital Loss, Hours-per-week, Native Country, Class]
# Index: []

# %%
df['Work Class'].mode()
# Out:
# 0     Private
# Name: Work Class, dtype: object

# %%
df[df['Occupation'] == ' ?']
# Out:
# Empty DataFrame
# Columns: [Age, Work Class, Final Weight, Education, Education Number, Marital Status, Occupation, Relationship, Race, Sex, Capital Gain, Capital Loss, Hours-per-week, Native Country, Class]
# Index: []

# %%
df['Class'].unique()
# Out:
# array([' <=50K', ' >50K'], dtype=object)

# %%
df[df['Class'] == ' >50K']
# Out:
#        Age         Work Class  Final Weight      Education  Education Number  \
# 7       52   Self-emp-not-inc        209642        HS-grad                 9
# 8       31            Private         45781        Masters                14
# 9       42            Private        159449      Bachelors                13
# 10      37            Private        280464   Some-college                10
# 11      30          State-gov        141297      Bachelors                13
# ...    ...                ...           ...            ...               ...
# 32539   71            Private        287372      Doctorate                16
# 32545   39          Local-gov        111499     Assoc-acdm                12
# 32554   53            Private        321865        Masters                14
# 32557   40            Private        154374        HS-grad                 9
# 32560   52       Self-emp-inc        287927        HS-grad                 9
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32561 entries, 0 to 32560
# Data columns (total 15 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Age               32561 non-null  int64
#  1   Work Class        32561 non-null  object
#  2   Final Weight      32561 non-null  int64
#  3   Education         32561 non-null  object
#  4   Education Number  32561 non-null  int64
#  5   Marital Status    32561 non-null  object
#  6   Occupation        32561 non-null  object
#  7   Relationship      32561 non-null  object
#  8   Race              32561 non-null  object
#  9   Sex               32561 non-null  object
#  10  Capital Gain      32561 non-null  int64
#  11  Capital Loss      32561 non-null  int64
#  12  Hours-per-week    32561 non-null  int64
#  13  Native Country    32561 non-null  object
#  14  Class             32561 non-null  object
# dtypes: int64(6), object(9)
# memory usage: 3.7+ MB

# %%
df[(df['Hours-per-week'] == 99) & (df['Sex'] == ' Male')]
# Out:
#        Age         Work Class  Final Weight      Education  Education Number  \
# 935     37            Private        176900        HS-grad                 9
# 1172    25            Private        404616        Masters                14
# 1887    55   Self-emp-not-inc        184425   Some-college                10
# 3578    37       Self-emp-inc        382802      Doctorate                16
# 4086    50            Private        174964           10th                 6
# ...    ...                ...           ...            ...               ...
# 30610   51   Self-emp-not-inc         24790   Some-college                10
# 30766   42   Self-emp-not-inc         39539        HS-grad                 9
# 30992   40       Self-emp-inc        104235        Masters                14
# 31681   43            Private        266324        HS-grad                 9
# 31699   43   Self-emp-not-inc        163108   Some-college                10
#
# ...

# %%
df[df['Hours-per-week'] == 99]
# Out:
#        Age         Work Class  Final Weight      Education  Education Number  \
# 935     37            Private        176900        HS-grad                 9
# 1172    25            Private        404616        Masters                14
# 1887    55   Self-emp-not-inc        184425   Some-college                10
# 3578    37       Self-emp-inc        382802      Doctorate                16
# 4086    50            Private        174964           10th                 6
# ...    ...                ...           ...            ...               ...
# 30992   40       Self-emp-inc        104235        Masters                14
# 31681   43            Private        266324        HS-grad                 9
# 31699   43   Self-emp-not-inc        163108   Some-college                10
# 32469   58       Self-emp-inc        181974      Doctorate                16
# 32531   30            Private         33811      Bachelors                13
#
# ...

# %%
df[(df['Hours-per-week'] == 99) & (df['Sex'] == ' Female')].shape
# Out:
# (19, 15)

# %%
df[df['Hours-per-week'] == max(df['Hours-per-week'])]
# Out:
#        Age         Work Class  Final Weight      Education  Education Number  \
# 935     37            Private        176900        HS-grad                 9
# 1172    25            Private        404616        Masters                14
# 1887    55   Self-emp-not-inc        184425   Some-college                10
# 3578    37       Self-emp-inc        382802      Doctorate                16
# 4086    50            Private        174964           10th                 6
# ...    ...                ...           ...            ...               ...
# 30992   40       Self-emp-inc        104235        Masters                14
# 31681   43            Private        266324        HS-grad                 9
# 31699   43   Self-emp-not-inc        163108   Some-college                10
# 32469   58       Self-emp-inc        181974      Doctorate                16
# 32531   30            Private         33811      Bachelors                13
#
# ...

# %%
df.iloc[0]
# Out:
# Age                             39
# Work Class               State-gov
# Final Weight                 77516
# Education                Bachelors
# Education Number                13
# Marital Status       Never-married
# Occupation            Adm-clerical
# Relationship         Not-in-family
# Race                         White
# Sex                           Male
# Capital Gain                  2174
# Capital Loss                     0
# Hours-per-week                  40
# Native Country       United-States
# Class                        <=50K
# Name: 0, dtype: object

# %%
df.loc[0]
# Out:
# Age                             39
# Work Class               State-gov
# Final Weight                 77516
# Education                Bachelors
# Education Number                13
# Marital Status       Never-married
# Occupation            Adm-clerical
# Relationship         Not-in-family
# Race                         White
# Sex                           Male
# Capital Gain                  2174
# Capital Loss                     0
# Hours-per-week                  40
# Native Country       United-States
# Class                        <=50K
# Name: 0, dtype: object

# %%
df.loc[2:10]
# Out:
#     Age         Work Class  Final Weight      Education  Education Number  \
# 2    38            Private        215646        HS-grad                 9
# 3    53            Private        234721           11th                 7
# 4    28            Private        338409      Bachelors                13
# 5    37            Private        284582        Masters                14
# 6    49            Private        160187            9th                 5
# 7    52   Self-emp-not-inc        209642        HS-grad                 9
# 8    31            Private         45781        Masters                14
# 9    42            Private        159449      Bachelors                13
# 10   37            Private        280464   Some-college                10
#
#             Marital Status          Occupation    Relationship    Race  \
# 2                 Divorced   Handlers-cleaners   Not-in-family   White
# 3       Married-civ-spouse   Handlers-cleaners         Husband   Black
# ...

# %%
df.groupby('Sex').sum().T
# Out:
# Sex                   Female        Male
# Age                   397000      859257
# Final Weight      2000673518  4178699874
# Education Number      108095      220142
# Capital Gain         6122350    28966974
# Capital Loss          659052     2183648
# Hours-per-week        392176      924508

# %%
df.groupby('Sex')['Hours-per-week'].sum().T
# Out:
# Sex
#  Female    392176
#  Male      924508
# Name: Hours-per-week, dtype: int64

# %%
df.isna().sum()
# Out:
# Age                 0
# Work Class          0
# Final Weight        0
# Education           0
# Education Number    0
# Marital Status      0
# Occupation          0
# Relationship        0
# Race                0
# Sex                 0
# Capital Gain        0
# Capital Loss        0
# Hours-per-week      0
# Native Country      0
# Class               0
# dtype: int64

# %%
df[df['Work Class'] == " ?"]
# Out:
# Empty DataFrame
# Columns: [Age, Work Class, Final Weight, Education, Education Number, Marital Status, Occupation, Relationship, Race, Sex, Capital Gain, Capital Loss, Hours-per-week, Native Country, Class]
# Index: []

# %%
import numpy as np

# %%
df['Work Class'] = df['Work Class'].replace(' ?', np.nan)

# %%
df[df['Work Class'] == " ?"]
# Out:
# Empty DataFrame
# Columns: [Age, Work Class, Final Weight, Education, Education Number, Marital Status, Occupation, Relationship, Race, Sex, Capital Gain, Capital Loss, Hours-per-week, Native Country, Class]
# Index: []

# %%
df['Occupation'] = df['Occupation'].replace(' ?', np.nan)

# %%
df['Native Country'] = df['Native Country'].replace(' ?', np.nan)

# %%
df.isna().sum() # replace with Mode since they are categorical features
# Out:
# Age                 0
# Work Class          0
# Final Weight        0
# Education           0
# Education Number    0
# Marital Status      0
# Occupation          0
# Relationship        0
# Race                0
# Sex                 0
# Capital Gain        0
# Capital Loss        0
# Hours-per-week      0
# Native Country      0
# Class               0
# dtype: int64

# %%
df['Work Class'].mode()[0]
# Out:
# ' Private'

# %%
df['Work Class'] = df['Work Class'].fillna(df['Work Class'].mode()[0])
df['Occupation'] = df['Occupation'].fillna(df['Occupation'].mode()[0])
df['Native Country'] = df['Native Country'].fillna(df['Native Country'].mode()[0])

# %%
df.isna().sum()
# Out:
# Age                 0
# Work Class          0
# Final Weight        0
# Education           0
# Education Number    0
# Marital Status      0
# Occupation          0
# Relationship        0
# Race                0
# Sex                 0
# Capital Gain        0
# Capital Loss        0
# Hours-per-week      0
# Native Country      0
# Class               0
# dtype: int64

# %%
df.head()
# Out:
#    Age         Work Class  Final Weight   Education  Education Number  \
# 0   39          State-gov         77516   Bachelors                13
# 1   50   Self-emp-not-inc         83311   Bachelors                13
# 2   38            Private        215646     HS-grad                 9
# 3   53            Private        234721        11th                 7
# 4   28            Private        338409   Bachelors                13
#
#         Marital Status          Occupation    Relationship    Race      Sex  \
# 0        Never-married        Adm-clerical   Not-in-family   White     Male
# 1   Married-civ-spouse     Exec-managerial         Husband   White     Male
# 2             Divorced   Handlers-cleaners   Not-in-family   White     Male
# 3   Married-civ-spouse   Handlers-cleaners         Husband   Black     Male
# 4   Married-civ-spouse      Prof-specialty            Wife   Black   Female
#
#    Capital Gain  Capital Loss  Hours-per-week  Native Country   Class
# ...

# %%
df.shape
# Out:
# (32561, 15)

# %%
df = df.drop_duplicates(keep='first') # 24 values are duplicated --> dropping them

# %%
df.shape
# Out:
# (32537, 15)

# %%
df['Class'].unique()
# Out:
# array([' <=50K', ' >50K'], dtype=object)

# %%
df.drop(['Final Weight','Capital Loss', 'Capital Gain'], axis= 1, inplace=True)
# Out:
# /var/folders/sd/ksvjn1650sbfvdvzr8hdh84c0000gn/T/ipykernel_4505/3484427470.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.drop(['Final Weight','Capital Loss', 'Capital Gain'], axis= 1, inplace=True)

# %%
df.columns
# Out:
# Index(['Age', 'Work Class', 'Education', 'Education Number', 'Marital Status',
#        'Occupation', 'Relationship', 'Race', 'Sex', 'Hours-per-week',
#        'Native Country', 'Class'],
#       dtype='object')

# %%
df.head()
# Out:
#    Age         Work Class   Education  Education Number       Marital Status  \
# 0   39          State-gov   Bachelors                13        Never-married
# 1   50   Self-emp-not-inc   Bachelors                13   Married-civ-spouse
# 2   38            Private     HS-grad                 9             Divorced
# 3   53            Private        11th                 7   Married-civ-spouse
# 4   28            Private   Bachelors                13   Married-civ-spouse
#
#            Occupation    Relationship    Race      Sex  Hours-per-week  \
# 0        Adm-clerical   Not-in-family   White     Male              40
# 1     Exec-managerial         Husband   White     Male              13
# 2   Handlers-cleaners   Not-in-family   White     Male              40
# 3   Handlers-cleaners         Husband   Black     Male              40
# 4      Prof-specialty            Wife   Black   Female              40
#
#    Native Country   Class
# 0   United-States   <=50K
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 32537 entries, 0 to 32560
# Data columns (total 12 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Age               32537 non-null  int64
#  1   Work Class        32537 non-null  object
#  2   Education         32537 non-null  object
#  3   Education Number  32537 non-null  int64
#  4   Marital Status    32537 non-null  object
#  5   Occupation        32537 non-null  object
#  6   Relationship      32537 non-null  object
#  7   Race              32537 non-null  object
#  8   Sex               32537 non-null  object
#  9   Hours-per-week    32537 non-null  int64
#  10  Native Country    32537 non-null  object
#  11  Class             32537 non-null  object
# dtypes: int64(3), object(9)
# memory usage: 3.2+ MB

# %%
df.isna().sum()
# Out:
# Age                 0
# Work Class          0
# Education           0
# Education Number    0
# Marital Status      0
# Occupation          0
# Relationship        0
# Race                0
# Sex                 0
# Hours-per-week      0
# Native Country      0
# Class               0
# dtype: int64

# %%
df.head(10)
# Out:
#    Age         Work Class   Education  Education Number  \
# 0   39          State-gov   Bachelors                13
# 1   50   Self-emp-not-inc   Bachelors                13
# 2   38            Private     HS-grad                 9
# 3   53            Private        11th                 7
# 4   28            Private   Bachelors                13
# 5   37            Private     Masters                14
# 6   49            Private         9th                 5
# 7   52   Self-emp-not-inc     HS-grad                 9
# 8   31            Private     Masters                14
# 9   42            Private   Bachelors                13
#
#            Marital Status          Occupation    Relationship    Race  \
# 0           Never-married        Adm-clerical   Not-in-family   White
# 1      Married-civ-spouse     Exec-managerial         Husband   White
# 2                Divorced   Handlers-cleaners   Not-in-family   White
# ...

# %%
df['Class'].unique()
# Out:
# array([' <=50K', ' >50K'], dtype=object)

# %%
df = pd.get_dummies(data=df,columns=['Class'],drop_first=True)

# %%
df.shape
# Out:
# (32537, 12)

# %%
df_original.shape
# Out:
# (32560, 15)

# %%
df.to_csv('Cleaned_Census_Data.csv',index = False) # do not print row name

# %%
df.isnull().sum()
# Out:
# Age                 0
# Work Class          0
# Education           0
# Education Number    0
# Marital Status      0
# Occupation          0
# Relationship        0
# Race                0
# Sex                 0
# Hours-per-week      0
# Native Country      0
# Class_ >50K         0
# dtype: int64

# %%
b = df[['Age','Sex','Occupation', 'Education', 'Native Country']]

# %%
b.head()
# Out:
#    Age      Sex          Occupation   Education  Native Country
# 0   39     Male        Adm-clerical   Bachelors   United-States
# 1   50     Male     Exec-managerial   Bachelors   United-States
# 2   38     Male   Handlers-cleaners     HS-grad   United-States
# 3   53     Male   Handlers-cleaners        11th   United-States
# 4   28   Female      Prof-specialty   Bachelors            Cuba
